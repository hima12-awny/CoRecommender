# %% [markdown]
# # CoRecommender - Usage Example
# A flexible collaborative filtering recommendation system that supports both item-based and user-based approaches using nearest neighbors with cosine similarity. Built with Python, NumPy, Pandas, and scikit-learn.

# %%
import numpy as np
import pandas as pd
from co_recommender import CoRecommender

# %% [markdown]
# ## Read Data Sources

# %% [markdown]
# the data must contains:
# 1. `uid`: user id, how made the interaction
# 2. `iid`: item id, that the interaction made on it.
# 3. `dynamic`: this user free column name, act as indicator of the interaction and it's scale means how mush user interacts with this item.
#
# `dynamic` means, you can name it whatever you want, it could be anything, but it should be Numeric Value.
# it could be for example rate, num_of_visits, likes, num_of_clicks...

# %% [markdown]
# #### Read it from CSV

# %%
users_interaction_data = pd.read_csv(
    'database/ratings.csv',
    usecols=['userId', 'movieId', 'rating'],
).rename(
    columns={
        'userId': 'uid',
        'movieId': 'iid',
        'rating': 'rate'
    })

movies = pd.read_csv(
    'database/movies.csv',
    index_col='movieId',
    converters={"genres": lambda x: ', '.join(sorted(x.split('|')))})

# %% [markdown]
# #### Read it from JSON

# %%
import json
with open('database/users_interaction_data_sample.json', 'r') as f:
    users_interaction_data_json = f.read()
    users_interaction_data = json.loads(users_interaction_data_json)
    users_interaction_data = pd.DataFrame(users_interaction_data)

# %%
print(users_interaction_data_json)
# Out:
# [
#     {
#         "uid": 1,
#         "iid": 1,
#         "rate": 4.0
#     },
#     {
#         "uid": 1,
#         "iid": 3,
#         "rate": 4.0
#     }
# ]

# %% [markdown]
# #### Preview

# %%
users_interaction_data
# Out:
#    uid  iid  rate
# 0    1    1   4.0
# 1    1    3   4.0
# 2    1    6   4.0
# 3    1   47   5.0
# 4    1   50   5.0

# %%
movies.head()
# Out:
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                                   genres
# movieId
# 1        Adventure, Animation, Children, Comedy, Fantasy
# 2                           Adventure, Children, Fantasy
# 3                                        Comedy, Romance
# 4                                 Comedy, Drama, Romance
# 5                                                 Comedy

# %% [markdown]
# ## Create CoRecommender
# you need to specify
# 1. `mode`: the tool handle two recommendations types, item-based and user-based, you should choose one type at once, <br> `user` -> user-based <br> `item` -> item-based.
# 2. `indic`: indication column name, `dynamic` colname like above, ex. rate.

# %%
recommendation_type = 'item'
interaction_indication_col = 'rate'

rec_sys = CoRecommender(
    mode=recommendation_type,
    indic=interaction_indication_col,
)

# %% [markdown]
# ### Train The model
# Means Convert the user-item interaction data into suitable formate and save it based on recommendation Type

# %%
rec_sys.train_model(users_interaction_data)

# %% [markdown]
# ### Running Sample

# %%
# get unique users and items
uids = users_interaction_data['uid'].unique()
rec_data = users_interaction_data

# %%
# get random user id for testing the model.
user_id = np.random.choice(uids)

# get all data for a specific user only.
user_preferred_products = rec_data[
    rec_data['uid'] == user_id][['iid', 'rate']]

user_preferred_products = user_preferred_products.sort_values(
    by='rate', ascending=False).reset_index(drop=True)

print(f'User id: {user_id}, Preferred Items:')
user_preferred_products.head()
# Out:
# User id: 343, Preferred Items:
#     iid  rate
# 0   527   5.0
# 1  4226   5.0
# 2  1213   5.0
# 3  2571   5.0
# 4  2959   5.0

# %% [markdown]
# ### Get Recommendations
#
# #### Parameters
# 1. `user_id`: that you want to get recommendation for him, and based on his behavior. `required` for user-based.
# 2. `user_prev_data`: user previous interaction data, that based on it get recommendations. `required` for item-based
# 3. `n_recommendations`: max number of recommendations items you want to get `required`.
# 4. `n_similar_entities`: for each item or user how much you wan to get similar items. `required`
# 5. `print_results`: print logs, `optional` with defaults `True`
#
# #### Returns
# in Case User-Based
# 1. `recommended_items_ids`: list of all recommended items ids.
# 2. `similar_users_id`:  list of all similar users ids.
#
# in Case Item-Based
# 1. `recommended_items_ids`: list of all recommended items ids.
# 2. `relative_recommendations`: this dictionary that contains the user preferred item id as key, and similar items ids that recommended based on this key.

# %%
# NOTE: you can't call or use this method before train the mode at least one time.
recommendations = rec_sys.recommend_items(
    user_id=user_id,  # user id to recommend items for.
    user_prev_data=user_preferred_products,  # user previous interactions.
    n_recommendations=200,  # number of items to recommend.
    n_similar_entities=10,  # number of similar items or users to get.
    print_results=False  # set to True if you want to print the results.
)

# %% [markdown]
# ### Show Relative Recommendations Results (Item-based)

# %%
if recommendation_type == 'item':
    user_watched_movies = set(user_preferred_products['iid'].values)
    print("Relative Recommendations:")

    relative_recs = recommendations['relative_recommendations']

    printed_mids = set()

    for i, (r_mid, r_mids) in enumerate(relative_recs.items(), 1):

        print(f'{i}. because user loved ->', ' - '.join(
            movies.loc[r_mid][['title', 'genres']].values))

        e = 0
        for m_id in r_mids:
            if m_id in user_watched_movies or m_id in printed_mids:
                continue

            printed_mids.add(m_id)
            e = e+1
            print(f'   {e}.', ' - '.join(
                movies.loc[m_id][['title', 'genres']].values))

        print('-'*100)
# Out:
# Relative Recommendations:
# 1. because user loved -> Schindler's List (1993) - Drama, War
#    1. Forrest Gump (1994) - Comedy, Drama, Romance, War
#    2. Saving Private Ryan (1998) - Action, Drama, War
#    3. Braveheart (1995) - Action, Drama, War
#    4. Sixth Sense, The (1999) - Drama, Horror, Mystery
#    5. Seven (a.k.a. Se7en) (1995) - Mystery, Thriller
#    6. Apollo 13 (1995) - Adventure, Drama, IMAX
#    7. Jurassic Park (1993) - Action, Adventure, Sci-Fi, Thriller
#    8. Fugitive, The (1993) - Thriller
#    9. Speed (1994) - Action, Romance, Thriller
#    10. Green Mile, The (1999) - Crime, Drama
#    11. Dances with Wolves (1990) - Adventure, Drama, Western
#    12. Fargo (1996) - Comedy, Crime, Drama, Thriller
# ----------------------------------------------------------------------------------------------------
# 2. because user loved -> Memento (2000) - Mystery, Thriller
#    1. Eternal Sunshine of the Spotless Mind (2004) - Drama, Romance, Sci-Fi
#    2. Kill Bill: Vol. 1 (2003) - Action, Crime, Thriller
#    3. Kill Bill: Vol. 2 (2004) - Action, Drama, Thriller
#    4. Clockwork Orange, A (1971) - Crime, Drama, Sci-Fi, Thriller
#    5. Prestige, The (2006) - Drama, Mystery, Sci-Fi, Thriller
#    6. Batman Begins (2005) - Action, Crime, IMAX
#    7. Requiem for a Dream (2000) - Drama
#    8. V for Vendetta (2006) - Action, IMAX, Sci-Fi, Thriller
#    9. Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001) - Comedy, Romance
#    10. Truman Show, The (1998) - Comedy, Drama, Sci-Fi
# ----------------------------------------------------------------------------------------------------
# 3. because user loved -> Goodfellas (1990) - Crime, Drama
#    1. Apocalypse Now (1979) - Action, Drama, War
#    2. Full Metal Jacket (1987) - Drama, War
#    3. Shining, The (1980) - Horror
#    4. Big Lebowski, The (1998) - Comedy, Crime
#    5. Ferris Bueller's Day Off (1986) - Comedy
#    6. One Flew Over the Cuckoo's Nest (1975) - Drama
#    7. Taxi Driver (1976) - Crime, Drama, Thriller
#    8. Monty Python and the Holy Grail (1975) - Adventure, Comedy, Fantasy
# ----------------------------------------------------------------------------------------------------
# 4. because user loved -> Matrix, The (1999) - Action, Sci-Fi, Thriller
#    1. Star Wars: Episode VI - Return of the Jedi (1983) - Action, Adventure, Sci-Fi
#    2. Gladiator (2000) - Action, Adventure, Drama
#    3. Terminator, The (1984) - Action, Sci-Fi, Thriller
#    4. Men in Black (a.k.a. MIB) (1997) - Action, Comedy, Sci-Fi
#    5. Star Wars: Episode I - The Phantom Menace (1999) - Action, Adventure, Sci-Fi
#    6. Indiana Jones and the Last Crusade (1989) - Action, Adventure
# ----------------------------------------------------------------------------------------------------
# 5. because user loved -> Fight Club (1999) - Action, Crime, Drama, Thriller
#    1. Inception (2010) - Action, Crime, Drama, IMAX, Mystery, Sci-Fi, Thriller
#    2. Dark Knight, The (2008) - Action, Crime, Drama, IMAX
# ----------------------------------------------------------------------------------------------------
# 6. because user loved -> Superbad (2007) - Comedy
#    1. Knocked Up (2007) - Comedy, Drama, Romance
#    2. Pineapple Express (2008) - Action, Comedy, Crime
#    3. Anchorman: The Legend of Ron Burgundy (2004) - Comedy
#    4. Harold and Kumar Go to White Castle (2004) - Adventure, Comedy
#    5. Hangover, The (2009) - Comedy, Crime
#    6. Super Troopers (2001) - Comedy, Crime, Mystery
#    7. I Love You, Man (2009) - Comedy
#    8. Role Models (2008) - Comedy
#    9. Zoolander (2001) - Comedy
#    10. Forgetting Sarah Marshall (2008) - Comedy, Romance
#    11. Napoleon Dynamite (2004) - Comedy
#    12. Tropic Thunder (2008) - Action, Adventure, Comedy, War
#    13. 3:10 to Yuma (2007) - Action, Crime, Drama, Western
#    14. 300 (2007) - Action, Fantasy, IMAX, War
#    15. Step Brothers (2008) - Comedy
#    16. Wedding Crashers (2005) - Comedy, Romance
#    17. Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006) - Comedy
# ----------------------------------------------------------------------------------------------------
# 7. because user loved -> Infernal Affairs (Mou gaan dou) (2002) - Crime, Drama, Thriller
#    1. Cinemania (2002) - Documentary
#    2. Hitman (2007) - Action, Crime, Thriller
#    3. Teenage Mutant Ninja Turtles (2014) - Action, Adventure, Comedy
#    4. Sin City: A Dame to Kill For (2014) - Action, Crime, Thriller
#    5. Saw (2003) - Crime, Horror
#    6. Descent, The (2005) - Adventure, Drama, Horror, Thriller
#    7. Black Dahlia, The (2006) - Crime, Drama, Mystery, Thriller
#    8. Spider (2002) - Drama, Mystery
#    9. Machete Kills (Machete 2) (2013) - Action, Crime, Thriller
#    10. May (2002) - Drama, Horror
#    11. Devil's Backbone, The (Espinazo del diablo, El) (2001) - Drama, Fantasy, Horror, Thriller, War
#    12. Bubba Ho-tep (2002) - Comedy, Horror
#    13. Spartan (2004) - Thriller
#    14. Tideland (2005) - Drama, Fantasy, Thriller
#    15. Edmond (2005) - Drama, Thriller
#    16. The Nice Guys (2016) - Crime, Mystery, Thriller
#    17. Visitor Q (Bizita Q) (2001) - Comedy, Drama, Horror
#    18. [REC]³ 3 Génesis (2012) - Horror, Thriller
#    19. Evil Dead, The (1981) - Fantasy, Horror, Thriller
# ----------------------------------------------------------------------------------------------------
# 8. because user loved -> City of God (Cidade de Deus) (2002) - Action, Adventure, Crime, Drama, Thriller
#    1. Old Boy (2003) - Mystery, Thriller
#    2. Lost in Translation (2003) - Comedy, Drama, Romance
#    3. Trainspotting (1996) - Comedy, Crime, Drama
# ----------------------------------------------------------------------------------------------------
# 9. because user loved -> Lord of the Rings: The Two Towers, The (2002) - Adventure, Fantasy
#    1. Pirates of the Caribbean: The Curse of the Black Pearl (2003) - Action, Adventure, Comedy, Fantasy
#    2. Spider-Man (2002) - Action, Adventure, Sci-Fi, Thriller
#    3. Shrek (2001) - Adventure, Animation, Children, Comedy, Fantasy, Romance
#    4. Minority Report (2002) - Action, Crime, Mystery, Sci-Fi, Thriller
#    5. Bourne Identity, The (2002) - Action, Mystery, Thriller
#    6. Monsters, Inc. (2001) - Adventure, Animation, Children, Comedy, Fantasy
#    7. Matrix Reloaded, The (2003) - Action, Adventure, IMAX, Sci-Fi, Thriller
#    8. Finding Nemo (2003) - Adventure, Animation, Children, Comedy
#    9. Ocean's Eleven (2001) - Crime, Thriller
# ----------------------------------------------------------------------------------------------------
# 10. because user loved -> Grave of the Fireflies (Hotaru no haka) (1988) - Animation, Drama, War
#    1. Kiki's Delivery Service (Majo no takkyûbin) (1989) - Adventure, Animation, Children, Drama, Fantasy
#    2. Man with the Movie Camera, The (Chelovek s kino-apparatom) (1929) - Documentary
#    3. Ikiru (1952) - Drama
#    4. Diary of a Country Priest (Journal d'un curé de campagne) (1951) - Drama
#    5. Millennium Actress (Sennen joyû) (2001) - Animation, Drama, Romance
#    6. Tale of Two Sisters, A (Janghwa, Hongryeon) (2003) - Drama, Horror, Mystery, Thriller
#    7. 5 Centimeters per Second (Byôsoku 5 senchimêtoru) (2007) - Animation, Drama, Romance
#    8. Passion of Joan of Arc, The (Passion de Jeanne d'Arc, La) (1928) - Drama
#    9. Punch-Drunk Love (2002) - Comedy, Drama, Romance
#    10. Dungeons & Dragons (2000) - Action, Adventure, Comedy, Fantasy
#    11. Salo, or The 120 Days of Sodom (Salò o le 120 giornate di Sodoma) (1976) - Drama
#    12. Filth (2013) - Comedy, Crime, Drama
#    13. Short Film About Killing, A (Krótki film o zabijaniu) (1988) - Crime, Drama
#    14. Impostors, The (1998) - Comedy
#    15. Hamlet (1948) - Drama
#    16. Gold Rush, The (1925) - Adventure, Comedy, Romance
#    17. Lost in La Mancha (2002) - Documentary
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### User Preferred Items

# %%
print("Top 10 movies rated by user: ")
top_10_movies = user_preferred_products.sort_values(
    'rate', ascending=False).head(10)

movies.merge(top_10_movies, left_index=True, right_on='iid')[
    ['title', 'genres', 'rate']].reset_index(drop=True)
# Out:
# Top 10 movies rated by user:
#                                             title  \
# 0                         Schindler's List (1993)
# 1                               Goodfellas (1990)
# 2                              Matrix, The (1999)
# 3                               Fight Club (1999)
# 4                                  Memento (2000)
# 5  Grave of the Fireflies (Hotaru no haka) (1988)
# 6   Lord of the Rings: The Two Towers, The (2002)
# 7             City of God (Cidade de Deus) (2002)
# 8          Infernal Affairs (Mou gaan dou) (2002)
# 9                                 Superbad (2007)
#
#                                       genres  rate
# 0                                 Drama, War   5.0
# 1                               Crime, Drama   5.0
# 2                   Action, Sci-Fi, Thriller   5.0
# 3             Action, Crime, Drama, Thriller   5.0
# 4                          Mystery, Thriller   5.0
# 5                      Animation, Drama, War   5.0
# 6                         Adventure, Fantasy   5.0
# 7  Action, Adventure, Crime, Drama, Thriller   5.0
# 8                     Crime, Drama, Thriller   5.0
# 9                                     Comedy   5.0

# %% [markdown]
# ### Recommended Items

# %%
print("Recommended Movies:")

rec_movies = movies.loc[recommendations['recommended_items_ids']]
rec_movies.head(10)
# Out:
# Recommended Movies:
#                                                      title  \
# movieId
# 356                                    Forrest Gump (1994)
# 61024                             Pineapple Express (2008)
# 56156                                        Hitman (2007)
# 6433     Man with the Movie Camera, The (Chelovek s kin...
# 2028                            Saving Private Ryan (1998)
# 1210     Star Wars: Episode VI - Return of the Jedi (1983)
# 148671                                          Saw (2003)
# 6713               Millennium Actress (Sennen joyû) (2001)
# 110                                      Braveheart (1995)
# 5110                                 Super Troopers (2001)
#
#                               genres
# movieId
# 356      Comedy, Drama, Romance, War
# 61024          Action, Comedy, Crime
# 56156        Action, Crime, Thriller
# 6433                     Documentary
# 2028              Action, Drama, War
# 1210       Action, Adventure, Sci-Fi
# 148671                 Crime, Horror
# 6713       Animation, Drama, Romance
# 110               Action, Drama, War
# 5110          Comedy, Crime, Mystery
